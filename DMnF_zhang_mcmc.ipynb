# %% [markdown]
# ### This code plots posterior distributions of the parameters of the SSH and the CDT model used in Gupta et al. (2025), implementing a DM-IGM distribution fit generated by Zhang et al. (2021, https://arxiv.org/abs/2011.14494) using Illustris-TNG

# %%
from IPython.display import clear_output
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import emcee
import corner
from IPython.display import display

# %%
sol_rad = 6.957e10 #cm
c = 299792458 * 100 #cm/s
parsec = 3.08568e18 #cm
jansky = 1e-23

# %% [markdown]
# ### Visualize SFR-SMD hybrid model posteriors with DM-IGM information from Zhang et al. (2021)

# %%
sampler = emcee.backends.HDFBackend("zhang_dmigm_data/mcmc_agEf.h5", read_only=True)
# flat_samples = sampler.get_chain(flat=True)
labels = [r"$\alpha$", r"$\gamma$", r"log(E$_{\rm char, \nu}$)", r"$f_{\rm Y}$"] #, r"log($\phi$)"
ndim = 4

# %%
fig, axes = plt.subplots(4, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = [r"$\alpha$", r"$\gamma$", r"log(E$_{\rm char, \nu}$)", r"$f_{\rm Y}$"] #, r"log($\phi$)"
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i], fontsize=13)
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number", fontsize=13);

# %%
tau = sampler.get_autocorr_time()
print(tau)
print(np.sum(tau))
# print(np.mean(sampler.acceptance_fraction), np.std(sampler.acceptance_fraction))
acceptance_fraction = sampler.accepted / sampler.iteration
print(np.mean(acceptance_fraction), np.std(acceptance_fraction))
# Out:
# [27.51291037 23.77682515 25.25736588 24.23645961]
# 100.78356101034808
# 0.20871875 0.007903106533632485

# %%
flat_samples = sampler.get_chain(discard=100, flat=True)
# flat_samples2 = sampler2.get_chain(discard=1000, thin=90, flat=True)
# flat_samples3 = sampler3.get_chain(discard=1000, thin=90, flat=True)
print(flat_samples.shape)

# Convert E_char to E_charnu
# flat_samples[:, 2] = np.log10(10**flat_samples[:,2]/6e8)

fig = corner.corner(
    flat_samples, labels=labels, show_titles=True, title_kwargs={'fontsize':13}, label_kwargs={'fontsize':18}, quantiles=[0.5]
);
for ax in fig.get_axes():
    ax.tick_params(axis='both', labelsize=13)
# fig.savefig('plots/cornerplot_shintech_mcmc_agEf.pdf')#jpg', dpi=300)
# Out:
# (92800, 4)

# %% [markdown]
# ### Visualize constant delay time model posteriors with DM-IGM information from Zhang et al. (2021)

# %%
sampler = emcee.backends.HDFBackend("zhang_dmigm_data/mcmc_agEt.h5", read_only=True)
# flat_samples = sampler.get_chain(flat=True)
labels = [r"$\alpha$", r"$\gamma$", r"log(E$_{\rm char, \nu}$)", r"$f_{\rm Y}$"] #, r"log($\phi$)"
ndim = 4

# %%
fig, axes = plt.subplots(4, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = [r"$\alpha$", r"$\gamma$", r"log(E$_{\rm char, \nu}$)", r"$f_{\rm Y}$"] #, r"log($\phi$)"
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i], fontsize=13)
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number", fontsize=13);

# %%
tau = sampler.get_autocorr_time()
print(tau)
print(np.sum(tau))
# print(np.mean(sampler.acceptance_fraction), np.std(sampler.acceptance_fraction))
acceptance_fraction = sampler.accepted / sampler.iteration
print(np.mean(acceptance_fraction), np.std(acceptance_fraction))
# Out:
# [25.94873399 26.34890883 23.55381922 27.69624754]
# 103.5477095771394
# 0.19848958333333336 0.008765456338741805

# %%
flat_samples = sampler.get_chain(discard=100, flat=True)
# flat_samples2 = sampler2.get_chain(discard=1000, thin=90, flat=True)
# flat_samples3 = sampler3.get_chain(discard=1000, thin=90, flat=True)
print(flat_samples.shape)

# Convert E_char to E_charnu
# flat_samples[:, 2] = np.log10(10**flat_samples[:,2]/6e8)

fig = corner.corner(
    flat_samples, labels=labels, show_titles=True, title_kwargs={'fontsize':13}, label_kwargs={'fontsize':18}, quantiles=[0.5]
);
for ax in fig.get_axes():
    ax.tick_params(axis='both', labelsize=13)
# fig.savefig('plots/cornerplot_shintech_mcmc_agEf.pdf')#jpg', dpi=300)
# Out:
# (92800, 4)
